# %%
import pandas as pd
import matplotlib.pyplot as plt

td = pd.read_csv('./TrainingData_test_result.csv') # Training data
pred = pd.read_csv('./PredictionData_test_result.csv') # Prediction data

td.head()
# Out:
#    735535  -1.458528757095337  -1.506921648979187
# 0  607138           -0.683082           -0.763688
# 1  758332           -3.754292           -3.729887
# 2    9610           -0.802862           -0.700195
# 3    6091           -3.454301           -3.472701
# 4  763318           -2.100014           -2.064863

# %% [markdown]
# Prediction data is tested on different types of materials. See `generateCIF_predicted.py` in the `Utils` direcory.

# %%
plt.scatter(td.iloc[:, 1], td.iloc[:, 2], label='Training data results')
plt.scatter(pred.iloc[:, 1], pred.iloc[:, 2], label="Prediction data results")
plt.xlabel('DFT Formation Energy (eV/atom)')
plt.ylabel('Predicted Formation energy (eV/atom)')
plt.legend()
plt.show()
